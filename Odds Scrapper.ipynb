# %%
import pandas as pd
from bs4 import BeautifulSoup as bs
import numpy as np
import requests as rq
import re

# %%
headers = {"user-agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36"}
website = rq.get("https://www.sportsbookreview.com/betting-odds/nfl-football/", headers=headers)

# %%
html = bs(website.content, 'html').find('section', class_="container-1H2R_ compact-royPT")
table = html.find_all("div", class_="eventMarketGridContainer-3QipG neverWrap-lD_Yj compact-2-t2Y")
print(table[0].prettify())
# Out:
# <div class="eventMarketGridContainer-3QipG neverWrap-lD_Yj compact-2-t2Y">
#  <div class="compactBettingOptionContainer-VVPjh" data-horizontal-eid="4143368">
#   <div class="compactBettingOption-1o6lt" data-vertical-sbid="time">
#    <div class="favoriteContainer-3HF1m">
#     <div class="favoriteIcon-1c0oI favoriteIcon-33ya4" data-cy="favorite-icon">
#      <i class="sbr-icon-favorites">
#      </i>
#     </div>
#    </div>
#    <div class="timeContainer-DaVJ-">
#     <span>
#      01:00 PM
#     </span>
#     <div>
#      <a class="h2h-2dYq3" href="/betting-odds/nfl-football/4143368/matchup/" rel="">
#       H2H
#      </a>
#      <span class="spacer-1Wgfy">
#       |
#      </span>
#      <a class="icon-1mlgs" data-cy="button-grid-linehistory" href="/betting-odds/nfl-football/4143368/line-history/" rel="">
#       <i class="sbr-icon-rating-guide">
#       </i>
#      </a>
#     </div>
#    </div>
#   </div>
#   <section class="threeColumns-37SQt">
# ...
